# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import statistics
from scipy.stats import mode

# %%
 # load datasets from seaborn 'tips'
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (244, 7)

# %%
df.ndim
# Out:
# 2

# %%
np.mean(df['total_bill'])
# Out:
# 19.78594262295082

# %%
np.median(df['total_bill'])
# Out:
# 17.795

# %%
mode(df['total_bill'])
# Out:
# ModeResult(mode=13.42, count=3)

# %%
df['total_bill'].value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %%
sns.kdeplot(df['total_bill'])
plt.axvline(np.mean(df['total_bill']), color='red')
plt.axvline(np.median(df['total_bill']), color='blue')
plt.axvline(mode(df['total_bill']).mode, color='black')
plt.show()

# %%
sns.boxplot(df['total_bill'])
sns.stripplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
df_iris = sns.load_dataset('iris')
df_iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.kdeplot(df_iris['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.histplot(df_iris['sepal_width'], kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
df_iris['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
sns.countplot(x=df_iris['species'])
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
np.percentile(df_iris['sepal_length'],[25, 75])
# Out:
# array([5.1, 6.4])

# %% [markdown]
# * 25% of entire distribution is less than 5.1
# * 75% of eniter distribution is less than 6.4

# %%
df[(df['sex']=='Male')& (df['smoker']=='Yes')]['tip'].mean()
# Out:
# 3.051166666666667

# %%
df.groupby(['sex','smoker','time','day']).mean()
# Out:
#                            total_bill       tip      size
# sex    smoker time   day
# Male   Yes    Lunch  Thur   19.171000  3.058000  2.300000
#                      Fri    11.386667  1.900000  1.666667
#                      Sat          NaN       NaN       NaN
#                      Sun          NaN       NaN       NaN
#               Dinner Thur         NaN       NaN       NaN
#                      Fri    25.892000  3.246000  2.400000
#                      Sat    21.837778  2.879259  2.629630
#                      Sun    26.141333  3.521333  2.600000
#        No     Lunch  Thur   18.486500  2.941500  2.500000
#                      Fri          NaN       NaN       NaN
#                      Sat          NaN       NaN       NaN
#                      Sun          NaN       NaN       NaN
#               Dinner Thur         NaN       NaN       NaN
#                      Fri    17.475000  2.500000  2.000000
#                      Sat    19.929063  3.256563  2.656250
# ...

# %%
df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df['day'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
df['day'].isna().sum()
# Out:
# 0

# %%
from collections import Counter
count = Counter(df_iris['species'])
type(count)
# Out:
# collections.Counter

# %%
for i,j in count.items():
  print(i, j)
# Out:
# setosa 50
# versicolor 50
# virginica 50

# %%
count.setosa
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-3d39b37ff246> in <cell line: 1>()
# ----> 1 count.setosa
#
# AttributeError: 'Counter' object has no attribute 'setosa'
