# %% [markdown]
# # Pandas Methods()

# %%
# initializing pandas
import pandas as pd

# %%
# pandas ingestion
df_hr = pd.read_csv("data/HR_comma_sep.csv")
df_hr
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# # .head()

# %%
# use .head() to review first five data 
df_hr.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
# use .head(10) to review first 10 data 
df_hr.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# ...

# %% [markdown]
# # .tail()

# %%
# use .tail() to review last five data
df_hr.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department salary
# 14994                      0    support    low
# 14995                      0    support    low
# 14996                      0    support    low
# ...

# %%
# use .tail(10) to review last 10 data
df_hr.tail(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14989                0.43             0.57               2
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14992                0.40             0.48               2
# 14993                0.76             0.83               6
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14989                   159                   3              1     1
# 14990                   228                   5              1     1
# 14991                   257                   4              0     1
# ...

# %% [markdown]
# # .shape

# %%
# use .shape to view the shape of data
df_hr.shape
# Out:
# (14999, 10)

# %% [markdown]
# # .index

# %%
# use .index to view the index of data
df_hr.index
# Out:
# RangeIndex(start=0, stop=14999, step=1)

# %% [markdown]
# # .columns

# %%
# use .columns to view the data of column
df_hr.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %% [markdown]
# # .dtypes

# %%
# use .dtypes to classify data type of data
df_hr.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# dtype: object

# %%
df_new = df_hr

# %%
df_new
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# # .rename()

# %%
# use .rename() to rename the column name
df_new.rename(columns = {'last_evaluation': 'kxa'}, inplace=True)

# %%
df_new
# Out:
#        satisfaction_level   kxa  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %% [markdown]
# # .values

# %%
# .values to view all value of dataset
df_hr.values
# Out:
# array([[0.38, 0.53, 2, ..., 0, 'sales', 'low'],
#        [0.8, 0.86, 5, ..., 0, 'sales', 'medium'],
#        [0.11, 0.88, 7, ..., 0, 'sales', 'medium'],
#        ...,
#        [0.37, 0.53, 2, ..., 0, 'support', 'low'],
#        [0.11, 0.96, 6, ..., 0, 'support', 'low'],
#        [0.37, 0.52, 2, ..., 0, 'support', 'low']], dtype=object)

# %% [markdown]
# # .info()

# %%
# use .info() to view all information of dataset
df_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   kxa                    14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# * DataFrame occuopies 1.1+ MB memory
# * Columns are of types: float64, int64, object
# * Total columns = 14999
# * No any columns contain null values

# %% [markdown]
# # .describe()

# %%
# use .describe() to view numerical operation information of dataset
df_hr.describe()
# Out:
#        satisfaction_level           kxa  number_project  average_montly_hours  \
# count        14999.000000  14999.000000    14999.000000          14999.000000
# mean             0.612834      0.716102        3.803054            201.050337
# std              0.248631      0.171169        1.232592             49.943099
# min              0.090000      0.360000        2.000000             96.000000
# 25%              0.440000      0.560000        3.000000            156.000000
# 50%              0.640000      0.720000        4.000000            200.000000
# 75%              0.820000      0.870000        5.000000            245.000000
# max              1.000000      1.000000        7.000000            310.000000
#
#        time_spend_company  Work_accident          left  promotion_last_5years
# count        14999.000000   14999.000000  14999.000000           14999.000000
# mean             3.498233       0.144610      0.238083               0.021268
# ...

# %% [markdown]
# * We get the summary of each dataframe column easily without the need for explicit computation
# * By default it includes only the numerical columns.
# * let's get description of object type only below cells

# %%
# use .describe(include='object') to view object operation information of dataset
df_hr.describe(include='object')
# Out:
#        Department salary
# count       14999  14999
# unique         10      3
# top         sales    low
# freq         4140   7316

# %% [markdown]
# * For object type, we get count, uinque, top item with frequency

# %% [markdown]
# #  Data Selection
# * The section covers differnt techniques to access columns,slice dataframe, get unique column values.
#     * select column(using[], and dot(.) operator)
#     * iloc
#     * loc
#     * unique() and nunique()
#     * value.counts()

# %%
# selecting single column
df_hr["satisfaction_level"]
# Out:
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.72
# 4        0.37
#          ...
# 14994    0.40
# 14995    0.37
# 14996    0.37
# 14997    0.11
# 14998    0.37
# Name: satisfaction_level, Length: 14999, dtype: float64

# %%
# selecting multiple columns
column_to_select = ['satisfaction_level','left']
df_hr[column_to_select]
# Out:
#        satisfaction_level  left
# 0                    0.38     1
# 1                    0.80     1
# 2                    0.11     1
# 3                    0.72     1
# 4                    0.37     1
# ...                   ...   ...
# 14994                0.40     1
# 14995                0.37     1
# 14996                0.37     1
# 14997                0.11     1
# 14998                0.37     1
#
# [14999 rows x 2 columns]

# %% [markdown]
# # .iloc
# * ways ti slice pandas dataframe via integer value.
# * it allows you ti select data from a DataFrame using integer indices for both rows and columns

# %%
# use .iloc to slicing
df_hr.iloc[0,0]
# Out:
# 0.38

# %%
df_hr.iloc[:3,-3:]
# Out:
#    promotion_last_5years Department  salary
# 0                      0      sales     low
# 1                      0      sales  medium
# 2                      0      sales  medium

# %% [markdown]
# # .loc
# * loc is used for label-based indexing
# * allows us to slic DataFrame using row label and column label instead os integer value as in loc

# %%
df_hr.loc[0, 'satisfaction_level']
# Out:
# 0.38

# %%
row_label = [0,1]
column_label = ['promotion_last_5years', 'Department', 'salary']
df_hr.loc[row_label, column_label]
# Out:
#    promotion_last_5years Department  salary
# 0                      0      sales     low
# 1                      0      sales  medium

# %% [markdown]
# # unique() and nunique()
# * unique() use to view the unique item of any column
# * nunique() use to view the number of unique item of any column

# %%
# use to view unique value of "left" column
df_hr['left'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# use to view number of unique value of "left" column
df_hr['left'].nunique()
# Out:
# 2

# %% [markdown]
# # value_counts()

# %%
# value_counts() use to count the number of unique value
df_hr['left'].value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %% [markdown]
# # Aggregation
# * Methods
#   * mean()
#   * median()
#   * std()
#   * sum()
#   * max()
#   * min()

# %%
df_hr["satisfaction_level"].mean()
# Out:
# 0.6128335222348156

# %%
df_hr["satisfaction_level"].median()
# Out:
# 0.64

# %%
df_hr["satisfaction_level"].std()
# Out:
# 0.24863065106114257

# %%
df_hr["satisfaction_level"].sum()
# Out:
# 9191.89

# %%
df_hr["satisfaction_level"].min()
# Out:
# 0.09

# %% [markdown]
# # Missing Data
# * Methods:
#   * isnull() or isna()
#   * notnull() or notna()
#   * dropna()
#   * fillna()

# %% [markdown]
# # isnull() isna()
# * Return True if DataFrame values are null
# * DataFrame methods to get nan values from columns.
# * it will considered null values it there are nan which is python default marker for null values.
# * you can use df.isnull() methods which is simply an alias of df,isna()

# %%
df_hr.isnull()
# Out:
#        satisfaction_level    kxa  number_project  average_montly_hours  \
# 0                   False  False           False                 False
# 1                   False  False           False                 False
# 2                   False  False           False                 False
# 3                   False  False           False                 False
# 4                   False  False           False                 False
# ...                   ...    ...             ...                   ...
# 14994               False  False           False                 False
# 14995               False  False           False                 False
# 14996               False  False           False                 False
# 14997               False  False           False                 False
# 14998               False  False           False                 False
#
#        time_spend_company  Work_accident   left  promotion_last_5years  \
# ...

# %%
df_hr.isnull().sum()
# Out:
# satisfaction_level       0
# kxa                      0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %% [markdown]
# # This mean there is not any missing value in our dataset

# %%
df_hr.notnull().sum(axis=0)
# Out:
# satisfaction_level       14999
# kxa                      14999
# number_project           14999
# average_montly_hours     14999
# time_spend_company       14999
# Work_accident            14999
# left                     14999
# promotion_last_5years    14999
# Department               14999
# salary                   14999
# dtype: int64

# %%
df_hr.dropna()
# Out:
#        satisfaction_level   kxa  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %% [markdown]
# # fillna()
# * filling missing values

# %%
df_hr.fillna(5)
# Out:
#        satisfaction_level   kxa  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %% [markdown]
# # Data Manipulation
# * Methods:
#     * replace()
#       * replace values from DataFrame
#         * df.replace({'old_Value':'new_value'})
#     * astype()
#       * change DataFrame column types
#         * df.astype({'col1': name_type})
#     * drop()
#     * sort_values()
#     * groupby()
#     * apply()

# %%
df_hr['left'].replace({1:"yes",0:"no"})
# Out:
# 0        yes
# 1        yes
# 2        yes
# 3        yes
# 4        yes
#         ...
# 14994    yes
# 14995    yes
# 14996    yes
# 14997    yes
# 14998    yes
# Name: left, Length: 14999, dtype: object

# %%
df_hr.astype({'left': bool})
# Out:
#        satisfaction_level   kxa  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %%
df_hr.drop('salary', axis =1)
# Out:
#        satisfaction_level   kxa  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %%
df_hr.sort_values(by="Work_accident", ascending = False)
# Out:
#        satisfaction_level   kxa  number_project  average_montly_hours  \
# 8078                 0.77  0.91               5                   268
# 3570                 0.50  0.60               3                   270
# 1784                 0.43  0.51               2                   149
# 6589                 0.64  0.64               3                   234
# 11800                0.67  0.91               2                   245
# ...                   ...   ...             ...                   ...
# 5310                 0.63  0.87               5                   248
# 5311                 0.86  0.75               5                   157
# 5312                 0.80  0.79               5                   240
# 5313                 0.55  0.58               5                   262
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %%
df_hr.groupby(['Department', 'promotion_last_5years']).sum()
# Out:
#                                    satisfaction_level      kxa  \
# Department  promotion_last_5years
# IT          0                                  757.10   878.10
#             1                                    1.36     1.45
# RandD       0                                  470.48   540.27
#             1                                   17.32    20.17
# accounting  0                                  437.97   539.70
#             1                                    8.54    10.79
# hr          0                                  432.99   514.35
#             1                                    9.53     9.49
# management  0                                  349.22   407.73
#             1                                   42.23    48.39
# marketing   0                                  502.66   584.87
#             1                                   28.10    29.36
# product_mng 0                                  558.91   644.71
# ...

# %% [markdown]
# ## Data Join
# - `Types are:`
#     1. Inner Join
#         - pd.merge(df1, df2, on='col_name', how='inner')
#     2. Left Outer Join
#         - pd.merge(df1, df2, on='col_name', how='left')
#     3. Right Outer Join
#         - pd.merge(df1, df2, on='col_name', how='right')
#     4. Full Outer Join
#         - pd.merge(df1, df2, on='col_name', how='outer')

# %%
# reset index to get employee id

df_hr_ = df_hr.reset_index()

# rename col index to emp_id
df_hr_.columns.values[0] = "emp_id"

df_hr_.head()
# Out:
#    emp_id  satisfaction_level   kxa  number_project  average_montly_hours  \
# 0       0                0.38  0.53               2                   157
# 1       1                0.80  0.86               5                   262
# 2       2                0.11  0.88               7                   272
# 3       3                0.72  0.87               5                   223
# 4       4                0.37  0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
df_depart = df_hr_[['emp_id','Department']]
df_hr_.drop('Department', axis=1, inplace=True)
df_hr_.head()
# Out:
#    emp_id  satisfaction_level   kxa  number_project  average_montly_hours  \
# 0       0                0.38  0.53               2                   157
# 1       1                0.80  0.86               5                   262
# 2       2                0.11  0.88               7                   272
# 3       3                0.72  0.87               5                   223
# 4       4                0.37  0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  salary
# 0                   3              0     1                      0     low
# 1                   6              0     1                      0  medium
# 2                   4              0     1                      0  medium
# 3                   5              0     1                      0     low
# 4                   3              0     1                      0     low

# %% [markdown]
# # 1. Inner join

# %%
# inner join based on employee id to get Department information

df_inner = pd.merge(df_hr_, df_depart, on='emp_id', how='inner')

df_inner.head()
# Out:
#    emp_id  satisfaction_level   kxa  number_project  average_montly_hours  \
# 0       0                0.38  0.53               2                   157
# 1       1                0.80  0.86               5                   262
# 2       2                0.11  0.88               7                   272
# 3       3                0.72  0.87               5                   223
# 4       4                0.37  0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  salary  \
# 0                   3              0     1                      0     low
# 1                   6              0     1                      0  medium
# 2                   4              0     1                      0  medium
# 3                   5              0     1                      0     low
# 4                   3              0     1                      0     low
#
#   Department
# 0      sales
# 1      sales
# 2      sales
# 3      sales
# ...
